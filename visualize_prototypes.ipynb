# %% [markdown]
# This takes a image path and displays it

# %%
import matplotlib.pyplot as plt
import math

# %%
paths = [
    f"../output/joint/reasonable_dataset_0.0/images/epoch-15/Diptera/Chironomidae/Tanytarsus/prototypes/prototype-img-original_with_self_act{i}.png" for i in range(16)
]

w = math.floor(math.sqrt(len(paths)))
h = math.ceil(len(paths) / w)

fig, axs = plt.subplots(h, w, figsize=(20, 20))
for i, path in enumerate(paths):
    img = plt.imread(path)
    ax = axs[i // w, i % w]
    ax.imshow(img)
    ax.axis('off')
fig.suptitle("Diptera>Chironomidae Prototypes", fontsize=30)
fig.tight_layout()
plt.show()
